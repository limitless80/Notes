# %%
pip install gensim

# %%
import gensim.downloader as api
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load model
model = api.load("glove-wiki-gigaword-100")

# Select sports words
words = ['football', 'basketball', 'cricket', 'tennis', 'swimming', 'golf', 'rugby', 'hockey', 'volleyball', 'baseball']
vectors = np.array([model[word] for word in words])

# Apply PCA
pca = PCA(n_components=2)
reduced_vectors = pca.fit_transform(vectors)

# Plot
plt.scatter(reduced_vectors[:, 0], reduced_vectors[:, 1])
for i, word in enumerate(words):
    plt.annotate(word, (reduced_vectors[i, 0], reduced_vectors[i, 1]))
plt.show()

# Generate 5 similar words for an input
input_word = "football"
similar_words = model.most_similar(input_word, topn=5)
print(f"Similar words to {input_word}: {similar_words}")
# Out:
# Similar words to football: [('soccer', 0.8732221722602844), ('basketball', 0.8555637001991272), ('league', 0.815336287021637), ('rugby', 0.8007532954216003), ('hockey', 0.7833694815635681)]
